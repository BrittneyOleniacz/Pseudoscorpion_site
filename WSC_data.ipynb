# %%
import pandas as pd
import numpy as np


#files to Load

fossildata_from_WSC2020 = "WSC2020_pseudoscorpiones.csv"


#Read files

WSC_data = pd.read_csv(fossildata_from_WSC2020)

# %%
WSC_data
# Out:
#                Order     SuperFamily         Family                Range  \
# 0    Paleosphyronida  Dracocheloidea  Dracochelidea    Devonian ‒ Recent
# 1   Heterospyhronida      Chtonoidea    Chthonoidea  Cretaceous ‒ Recent
# 2   Heterospyhronida      Chtonoidea    Chthoniidae  Cretaceous ‒ Recent
# 3   Heterospyhronida      Chtonoidea    Chthoniidae  Cretaceous ‒ Recent
# 4   Heterospyhronida      Chtonoidea    Chthoniidae  Cretaceous ‒ Recent
# ..               ...             ...            ...                  ...
# 80        Panctenata   Cheliferoidea      Withiidae   Paleogene ‒ Recent
# 81        Panctenata   Cheliferoidea      Withiidae   Paleogene ‒ Recent
# 82        Panctenata   Cheliferoidea      Withiidae   Paleogene ‒ Recent
# 83            indet.          indet.   NOMUM DUBIUM               indet.
# 84            indet.          indet.    NOMUM NUDUM               indet.
#
#                     Genus      Species                           Author  \
# 0              Dracochela  deprehendor  Schwaller, Shear & Bonamo, 1991
# 1                  indet.       indet.             Ahrens et al. (2019)
# 2            Chelignathus       kochii     Menge in Koch & Berendt 1854
# 3   Chthonius (Chthonius)       mengei                      Beier, 1937
# 4   Chthonius (Chthonius)    pristinus                  Schwaller, 1978
# ..                    ...          ...                              ...
# 80                 indet.       indet.          in Ahrens et al. (2019)
# 81          Beierowithius   sieboldtii   (Menge in Koch & Berendt 1854)
# 82                Withius     eucarpus                   (Dalman, 1826)
# 83               Chelifer  ehrenbergii        C.L. Koch & Berendt, 1854
# 84               Chelifer     fossilis                 Weyenbergh, 1874
#
#    Type Locality Type Age range
# 0         Gilboa       Devonian
# 1     Bitterfeld      Paleogene
# 2         Baltic      Paleogene
# 3         Baltic      Paleogene
# 4         Baltic      Paleogene
# ..           ...            ...
# 80    Bitterfeld      Paleogene
# 81        Baltic      Paleogene
# 82   East Africa     Quaternary
# 83        Baltic      Paleogene
# 84     Solnhofen       Jurassic
#
# [85 rows x 9 columns]

# %%
by_locality = WSC_data.groupby("Type Age range")
by_locality.head()
# Out:
#                Order     SuperFamily                    Family  \
# 0    Paleosphyronida  Dracocheloidea             Dracochelidea
# 1   Heterospyhronida      Chtonoidea               Chthonoidea
# 2   Heterospyhronida      Chtonoidea               Chthoniidae
# 3   Heterospyhronida      Chtonoidea               Chthoniidae
# 4   Heterospyhronida      Chtonoidea               Chthoniidae
# 5   Heterospyhronida      Chtonoidea               Chthoniidae
# 6   Heterospyhronida      Chtonoidea               Chthoniidae
# 7   Heterospyhronida      Chtonoidea               Chthoniidae
# 8   Heterospyhronida      Chtonoidea               Chthoniidae
# 9   Heterospyhronida      Chtonoidea               Chthoniidae
# 10  Heterospyhronida      Chtonoidea               Chthoniidae
# 11  Heterospyhronida      Chtonoidea                Lechytidae
# 12  Heterospyhronida      Chtonoidea  Pseudotyrannochthoniidae
# 13    Homosyphronida             NaN                       NaN
# 15   Atoposyphronida     Feaelloidea                Feaellidae
# 22        Iochierata             NaN                       NaN
# 23       Hemictenata     Neobisoidea                Bochicidae
# 24       Hemictenata     Neobisoidea             Gymnobisiidae
# 43        Panctenata    Garypinoidea               Garypinidae
# 48        Panctenata    Cheirdioidea                Cheiriidae
# 49        Panctenata    Cheirdioidea                Cheiriidae
# 54        Panctenata   Cheliferoidea                 Atemnidae
# 57        Panctenata   Cheliferoidea              Cheliferidae
# 79        Panctenata   Cheliferoidea               Chernetidae
# 82        Panctenata   Cheliferoidea                 Withiidae
# 84            indet.          indet.               NOMUM NUDUM
#
#                   Range                              Genus           Species  \
# 0     Devonian ‒ Recent                         Dracochela       deprehendor
# 1   Cretaceous ‒ Recent                             indet.            indet.
# 2   Cretaceous ‒ Recent                       Chelignathus            kochii
# 3   Cretaceous ‒ Recent              Chthonius (Chthonius)            mengei
# 4   Cretaceous ‒ Recent              Chthonius (Chthonius)         pristinus
# 5   Cretaceous ‒ Recent                           Lechytia         tertiaria
# 6   Cretaceous ‒ Recent                   Paraliochthonius           miomaya
# 7   Cretaceous ‒ Recent                    Pseudochthonius         squamosus
# 8   Cretaceous ‒ Recent                    Tyrannchthonius               sp.
# 9   Cretaceous ‒ Recent                    Tyrannchthonius               sp.
# 10  Cretaceous ‒ Recent                      Weygoldtiella           plausus
# 11     Neogene ‒ Recent                             indet.            indet.
# 12   Paleogene ‒ Recent                             indet.            indet.
# 13  Cretaceous ‒ Recent                             indet.            indet.
# 15  Cretaceous ‒ Recent                       Protofeaella         peetersae
# 22  Cretaceous ‒ Recent                             indet.            indet.
# 23               Recent                             indet.            indet.
# 24               Recent                             indet.            indet.
# 43  Cretaceous ‒ Recent                        Amblyolpium        burmiticum
# 48  Cretaceous ‒ Recent  Cyptocheiridium (Cyptocheiridium)          antiquum
# 49  Cretaceous ‒ Recent                      Electrobisium            acutum
# 54   Paleogene ‒ Recent                      Paratemnoides       nidificator
# 57  Cretaceous ‒ Recent                            indet.                NaN
# 79  Cretaceous ‒ Recent                       Pachychernes  aff. Subrobustus
# 82   Paleogene ‒ Recent                            Withius          eucarpus
# 84               indet.                           Chelifer          fossilis
#
#                                     Author Type Locality Type Age range
# 0          Schwaller, Shear & Bonamo, 1991        Gilboa       Devonian
# 1                     Ahrens et al. (2019)    Bitterfeld      Paleogene
# 2             Menge in Koch & Berendt 1854        Baltic      Paleogene
# 3                              Beier, 1937        Baltic      Paleogene
# 4                          Schwaller, 1978        Baltic      Paleogene
# 5                          Schwaller, 1978     Dominican        Neogene
# 6                             Judson, 2016       Chiapas        Neogene
# 7                          Schwaller, 1980     Dominican        Neogene
# 8                         in Judson (2010)    Madagascar     Quaternary
# 9                         in Judson (2016)       Chiapas        Neogene
# 10                      Harvey et al. 2018       Burmese     Cretaceous
# 11                                     NaN           NaN            NaN
# 12                    Ahrens et al. (2019)    Bitterfeld      Paleogene
# 13                                     NaN           NaN            NaN
# 15  Henderickx in Henderickx & Boone, 2016       Burmese     Cretaceous
# 22                                     NaN           NaN            NaN
# 23                                     NaN           NaN            NaN
# 24                                     NaN           NaN            NaN
# 43                         Cockerell, 1920       Burmese     Cretaceous
# 48                         Schwaller, 1981     Dominican        Neogene
# 49                         Cockerell, 1917       Burmese     Cretaceous
# 54                          (Balzan, 1888)     Colombian     Quaternary
# 57                        in Judson (2009)    Archingeay     Cretaceous
# 79                          (Balzan, 1892)     Colombian     Quaternary
# 82                          (Dalman, 1826)   East Africa     Quaternary
# 84                        Weyenbergh, 1874     Solnhofen       Jurassic

# %%
WSC_data["Family"].describe()
# Out:
# count              83
# unique             31
# top       Chthoniidae
# freq                9
# Name: Family, dtype: object

# %%
WSC_data["Family"].unique()
# Out:
# array(['Dracochelidea', 'Chthonoidea', 'Chthoniidae', 'Lechytidae',
#        'Pseudotyrannochthoniidae', nan, 'Feaellidae', 'Pseudogarypidae',
#        'Bochicidae', 'Gymnobisiidae', 'Hyidae', 'Ideoroncidae',
#        'Neobisiidae', 'Parahyidae', 'Syarinidae', 'Garypidae',
#        'Geogarypidae', 'Hesperolpiidae', 'Methidae', 'Olpiidae',
#        'Garypinidae', 'Larcidae', 'Cheiriidae', 'Pseudochiridiidae',
#        'Sternophoridae', 'Atemnidae', 'Cheliferidae', 'Electrochelifer',
#        'Chernetidae', 'Withiidae', 'NOMUM DUBIUM', 'NOMUM NUDUM'],
#       dtype=object)

# %%
WSC_data["Author"].describe()
# Out:
# count              71
# unique             40
# top       Beier, 1937
# freq               11
# Name: Author, dtype: object

# %%
WSC_data["Author"].unique()
# Out:
# array(['Schwaller, Shear & Bonamo, 1991', 'Ahrens et al. (2019)',
#        'Menge in Koch & Berendt 1854', 'Beier, 1937', 'Schwaller, 1978',
#        'Judson, 2016', 'Schwaller, 1980', 'in Judson (2010)',
#        'in Judson (2016)', 'Harvey et al. 2018', nan,
#        'Henderickx in Henderickx & Boone, 2014',
#        'Henderickx in Henderickx & Boone, 2016',
#        '(C.L. Koch & Berendt, 1854)',
#        'Henderickx in Henderickx et al., 2006',
#        'Henderickx in Henderickx et al. 2012', 'Beier, 1955',
#        'Judson, 2003', 'Henderix, 2005', 'Cockerell, 1920',
#        'Schwaller, 1981', 'Cockerell, 1917', 'Judson, 2007',
#        '(Hoff, 1963)', '(Balzan, 1888)', 'in Beier, 1955',
#        'in Judson (2009)', 'in Ahrens et al. (2019)', 'Beier, 1947',
#        'Dashdamirmov, 2008', 'Judson, 2009', 'Hong, 1983',
#        'Schawaller (1991)', 'Schawaller (1982)',
#        '(Riqueime et al. 2014 in Riqueime et al.(2014))',
#        '(Menge in Koch & Berendt 1854)', 'Schawaller, 1980',
#        '(Balzan, 1892)', '(Dalman, 1826)', 'C.L. Koch & Berendt, 1854',
#        'Weyenbergh, 1874'], dtype=object)
