# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Pseudoscorpions of the World
# Harvey, M.S. (2013). Pseudoscorpions of the World, version 3.0. Western Australian Museum, Perth. http://www.museum.wa.gov.au/catalogues/pseudoscorpions

# %%
references = "PBDB_data/references2.csv"
citation_data = pd.read_csv(references)

citation_data
# Out:
#    author1init author1last author2init     author2last  \
# 0            W  Schawaller         NaN             NaN
# 1        P. A.   Latreille         NaN             NaN
# 2     T. D. A.   Cockerell         NaN             NaN
# 3        M. E.     Clapham         NaN             NaN
# 4     M. L. I.      Judson         NaN             NaN
# 5     T. D. A.   Cockerell         NaN             NaN
# 6     M. L. I.      Judson         NaN             NaN
# 7        W. D.      Pierce          J.          Gibron
# 8        J. A.      Dunlop          D.          Penney
# 9        C. L.        Koch       G. C.         Berendt
# 10       J. W.      Shultz         NaN             NaN
# 11          W.  Schawaller         NaN             NaN
# 12          W.  Schawaller         NaN             NaN
# 13          W.  Schawaller         NaN             NaN
# 14          A.       Menge         NaN             NaN
# 15          W.  Schawaller         NaN             NaN
# 16    M. L. I.      Judson         NaN             NaN
# 17       J. W.      Dalman         NaN             NaN
# 18          M.       Beier         NaN             NaN
# 19    M. L. I.      Judson         NaN             NaN
# 20          W.  Schawaller       W. A.           Shear
# 21          W.  Schawaller         NaN             NaN
# 22    M. L. I.      Judson         NaN             NaN
# 23    M. L. I.      Judson         NaN             NaN
# 24    M. L. I.      Judson         NaN             NaN
# 25          H.  Henderickx         NaN             NaN
# 26          H.  Henderickx         NaN             NaN
# 27          H.  Henderickx       E. E.       Perkovsky
# 28          H.  Henderickx         NaN             NaN
# 29          M.       Beier         NaN             NaN
# 30    M. L. I.      Judson         NaN             NaN
# 31       A. J.        Ross       P. V.            York
# 32          F.    Riquelme       D. F.  Piedra-Jiménez
# 33          M.       Beier         NaN             NaN
# 34       E. L.    Geoffroy         NaN             NaN
# 35       J. C.   Schaeffer         NaN             NaN
# 36    M. L. I.      Judson         NaN             NaN
# 37          H.  Henderickx         NaN             NaN
# 38       A. R.     Schmidt          U.        Kaulfuss
# 39       M. S.      Harvey       J. G.        Cosgrove
#
#                                          otherauthors  pubyr  \
# 0                                                 NaN   1991
# 1                                                 NaN   1802
# 2                                                 NaN   1917
# 3                                                 NaN   2020
# 4                                                 NaN   2003
# 5                                                 NaN   1920
# 6                                                 NaN   2000
# 7                                                 NaN   1962
# 8                                            D. Jekel   2013
# 9                                                 NaN   1854
# 10                                                NaN   2007
# 11                                                NaN   1980
# 12                                                NaN   1980
# 13                                                NaN   1978
# 14                                                NaN   1854
# 15                                                NaN   1981
# 16                                                NaN   2010
# 17                                                NaN   1826
# 18                                                NaN   1947
# 19                                                NaN   2012
# 20                                       P. M. Bonamo   1991
# 21                                                NaN   1981
# 22                                                NaN   2009
# 23                                                NaN   2003
# 24                                                NaN   1998
# 25                                                NaN   2005
# 26                                                NaN   2012
# 27                                                NaN   2012
# 28                                                NaN   2006
# 29                                                NaN   1955
# 30                                                NaN   2007
# 31                                                NaN   2000
# 32                                 V. Córdova-Tabares   2014
# 33                                                NaN   1937
# 34                                                NaN   1762
# 35                                                NaN   1766
# 36                                                NaN   2016
# 37                                                NaN   2016
# 38  J. M. Bannister, V. Baranov, C. Beimforde, N. ...   2018
# 39     D. Harms, P. A. Selden, C. K. Shih, C. C. Wang   2018
#
#                                              reftitle  \
# 0   The first Mesozoic pseudoscorpion, from Cretac...
# 1                                                 NaN
# 2                         Arthropods in Burmese amber
# 3   Insect taxonomy information from the internet,...
# 4   Baltic amber pseudoscorpions (Arachnida, Chelo...
# 5   T. D. A. Cockerell. 1920. Fossil Arthropods in...
# 6   Electrobisium acutum Cockerell, a cheiridiid p...
# 7   Fossil arthropods of California. 24. Some unus...
# 8   A summary list of fossil spiders and their rel...
# 9   Die im Bernstein befindlichen Crustaceen, Myri...
# 10  A phylogenetic analysis of the arachnid orders...
# 11  Erstnachweis tertiärer Pseudoskorpione (Cherne...
# 12  Fossile Chthoniidae in Dominikanischem Bernste...
# 13  Neue Pseudoskorpione aus dem Baltischen Bernst...
# 14  Footnotes and taxonomic names, in Die im Berns...
# 15  Pseudoskorpione (Cheliferidae) phoretisch auf ...
# 16  Redescription of Chelifer eucarpus Dalman (Ara...
# 17  Om insekter inneslutne i Copal; jemte beskrifn...
# 18  Pseudoskorpione im baltischen Bernstein und di...
# 19  Reinterpretation of Dracochela deprehendor (Ar...
# 20  The first Paleozoic pseudoscorpions (Arachnida...
# 21  Cheiridiidae in Dominikanischem Bernstein, mit...
# 22  Cheliferoid pseudoscorpions (Arachnida, Chelon...
# 23  Baltic amber fossil Garypinus electri Beier pr...
# 24  A sternophorid pseudoscorpion (Chelonethi) in ...
# 25  A new Geogarypus from Baltic amber Pseudoscorp...
# 26  Taxonomic names, in Phase-contrast synchrotron...
# 27  The first geogarypid (Pseudoscorpiones, Geogar...
# 28  Taxonomic names, in Description of a new fossi...
# 29  Pseudoscorpione im baltischen Bernstein aus de...
# 30  First fossil record of the pseudoscorpion fami...
# 31  A list of type and figured specimens of insect...
# 32  Taxonomic names, in A new chernetid pseudoscor...
# 33       Pseudoscorpione aus dem baltischen Bernstein
# 34                                                NaN
# 35                                                NaN
# 36  Pseudoscorpions (Arachnida, Chelonethi) in Mex...
# 37  Systematics, in The basal pseudoscorpion famil...
# 38                  Amber inclusions from New Zealand
# 39  The oldest chthonioid pseudoscorpion Arachnida...
#
#                                              pubtitle  pubvol  pubno  \
# 0                                       Palaeontology    34.0      4
# 1   Histoire Naturelle, Générale et Particulière d...     NaN    NaN
# 2               American Journal of Science, Series 4    44.0    263
# 3                                                 NaN     NaN    NaN
# 4                                       Geodiversitas    25.0      3
# 5   The Annals and Magazine of Natural History, Ni...     5.0    NaN
# 6   Bulletin of the Natural History Museum, Geolog...    56.0    NaN
# 7   Bulletin of the Southern California Academy of...    61.0    NaN
# 8   The World Spider Catalog, version 14.0. Americ...     NaN    NaN
# 9   Die in Bernstein Befindlichen Organischen Rest...     1.0      2
# 10          Zoological Journal of the Linnean Society   150.0    NaN
# 11  Stuttgarter Beiträge zur Naturkunde Serie B (G...    57.0    NaN
# 12  Stuttgarter Beiträge zur Naturkunde Serie B (G...    63.0    NaN
# 13  Stuttgarter Beiträge zur Naturkunde Serie B (G...    42.0    NaN
# 14  Die in Bernstein Befindlichen Organischen Rest...     1.0      2
# 15  Stuttgarter Beiträge zur Naturkunde Serie B (G...    71.0    NaN
# 16                                    Palaeodiversity     3.0    NaN
# 17  Kongliga Svenska Vetenskaps-Akademiens Handlingar  1825.0    NaN
# 18                                  Mikroscopie, Wien     1.0    NaN
# 19                                      Palaeontology    55.0    NaN
# 20                          American Museum Novitates  3009.0    NaN
# 21  Stuttgarter Beiträge zur Naturkunde Serie B (G...    75.0    NaN
# 22                                      Geodiversitas    31.0    NaN
# 23                  Arthropoda Selecta, Special Issue     1.0    NaN
# 24                         The Journal of Arachnology    26.0    NaN
# 25                                             Phegea    33.0    NaN
# 26                         Palaeontologia Electronica    15.0  2.17A
# 27                                   Vestnik Zoologii    46.0    NaN
# 28                                            Zootaxa  1305.0    NaN
# 29  Mitteilungen aus dem Geologisch-Paläontologisc...    24.0    NaN
# 30                                            Zootaxa  1393.0    NaN
# 31  Bulletin of the Natural History Museum, Geolog...    56.0    NaN
# 32                 Canadian Journal of Earth Sciences    51.0    NaN
# 33  Festschrift zum 60 Geburtstage von Professor D...     2.0    NaN
# 34  Histoire Abregée des Insectes qui se Trouvent ...     NaN    NaN
# 35  Elementa Entomologica. CXXXV. Tabulae aere Exc...     NaN    NaN
# 36          Boletín de la Sociedad Geológica Mexicana    68.0    NaN
# 37                                        Entomo-Info    27.0    NaN
# 38                                  Gondwana Research    56.0    NaN
# 39                              Zoologischer Anzeiger   273.0    NaN
#
#    firstpage lastpage
# 0        971      976
# 1          1      467
# 2        360      368
# 3        NaN      NaN
# 4        445      450
# 5        273      279
# 6         79       83
# 7        143      151
# 8        NaN      NaN
# 9          1      124
# 10       221      265
# 11         1       20
# 12         1       19
# 13         1       21
# 14         1      124
# 15         1       17
# 16        33       42
# 17       375      410
# 18       188      199
# 19       261      283
# 20         1       17
# 21         1       14
# 22        61       71
# 23       127      131
# 24       419      428
# 25        87       92
# 26         1       11
# 27       e33      e36
# 28        41       50
# 29        48       54
# 30        45       51
# 31        11       20
# 32       902      908
# 33       302      316
# 34         1      690
# 35       NaN      NaN
# 36        57       79
# 37         7       12
# 38       135      146
# 39       102      111

# %%
# Import our data into pandas from CSV
author_string = 'PBDB_data/references2.csv'
author_df = pd.read_csv(citation_string)

author_df
# Out:
#    author1init author1last author2init     author2last  \
# 0            W  Schawaller         NaN             NaN
# 1        P. A.   Latreille         NaN             NaN
# 2     T. D. A.   Cockerell         NaN             NaN
# 3        M. E.     Clapham         NaN             NaN
# 4     M. L. I.      Judson         NaN             NaN
# 5     T. D. A.   Cockerell         NaN             NaN
# 6     M. L. I.      Judson         NaN             NaN
# 7        W. D.      Pierce          J.          Gibron
# 8        J. A.      Dunlop          D.          Penney
# 9        C. L.        Koch       G. C.         Berendt
# 10       J. W.      Shultz         NaN             NaN
# 11          W.  Schawaller         NaN             NaN
# 12          W.  Schawaller         NaN             NaN
# 13          W.  Schawaller         NaN             NaN
# 14          A.       Menge         NaN             NaN
# 15          W.  Schawaller         NaN             NaN
# 16    M. L. I.      Judson         NaN             NaN
# 17       J. W.      Dalman         NaN             NaN
# 18          M.       Beier         NaN             NaN
# 19    M. L. I.      Judson         NaN             NaN
# 20          W.  Schawaller       W. A.           Shear
# 21          W.  Schawaller         NaN             NaN
# 22    M. L. I.      Judson         NaN             NaN
# 23    M. L. I.      Judson         NaN             NaN
# 24    M. L. I.      Judson         NaN             NaN
# 25          H.  Henderickx         NaN             NaN
# 26          H.  Henderickx         NaN             NaN
# 27          H.  Henderickx       E. E.       Perkovsky
# 28          H.  Henderickx         NaN             NaN
# 29          M.       Beier         NaN             NaN
# 30    M. L. I.      Judson         NaN             NaN
# 31       A. J.        Ross       P. V.            York
# 32          F.    Riquelme       D. F.  Piedra-Jiménez
# 33          M.       Beier         NaN             NaN
# 34       E. L.    Geoffroy         NaN             NaN
# 35       J. C.   Schaeffer         NaN             NaN
# 36    M. L. I.      Judson         NaN             NaN
# 37          H.  Henderickx         NaN             NaN
# 38       A. R.     Schmidt          U.        Kaulfuss
# 39       M. S.      Harvey       J. G.        Cosgrove
#
#                                          otherauthors  pubyr  \
# 0                                                 NaN   1991
# 1                                                 NaN   1802
# 2                                                 NaN   1917
# 3                                                 NaN   2020
# 4                                                 NaN   2003
# 5                                                 NaN   1920
# 6                                                 NaN   2000
# 7                                                 NaN   1962
# 8                                            D. Jekel   2013
# 9                                                 NaN   1854
# 10                                                NaN   2007
# 11                                                NaN   1980
# 12                                                NaN   1980
# 13                                                NaN   1978
# 14                                                NaN   1854
# 15                                                NaN   1981
# 16                                                NaN   2010
# 17                                                NaN   1826
# 18                                                NaN   1947
# 19                                                NaN   2012
# 20                                       P. M. Bonamo   1991
# 21                                                NaN   1981
# 22                                                NaN   2009
# 23                                                NaN   2003
# 24                                                NaN   1998
# 25                                                NaN   2005
# 26                                                NaN   2012
# 27                                                NaN   2012
# 28                                                NaN   2006
# 29                                                NaN   1955
# 30                                                NaN   2007
# 31                                                NaN   2000
# 32                                 V. Córdova-Tabares   2014
# 33                                                NaN   1937
# 34                                                NaN   1762
# 35                                                NaN   1766
# 36                                                NaN   2016
# 37                                                NaN   2016
# 38  J. M. Bannister, V. Baranov, C. Beimforde, N. ...   2018
# 39     D. Harms, P. A. Selden, C. K. Shih, C. C. Wang   2018
#
#                                              reftitle  \
# 0   The first Mesozoic pseudoscorpion, from Cretac...
# 1                                                 NaN
# 2                         Arthropods in Burmese amber
# 3   Insect taxonomy information from the internet,...
# 4   Baltic amber pseudoscorpions (Arachnida, Chelo...
# 5   T. D. A. Cockerell. 1920. Fossil Arthropods in...
# 6   Electrobisium acutum Cockerell, a cheiridiid p...
# 7   Fossil arthropods of California. 24. Some unus...
# 8   A summary list of fossil spiders and their rel...
# 9   Die im Bernstein befindlichen Crustaceen, Myri...
# 10  A phylogenetic analysis of the arachnid orders...
# 11  Erstnachweis tertiärer Pseudoskorpione (Cherne...
# 12  Fossile Chthoniidae in Dominikanischem Bernste...
# 13  Neue Pseudoskorpione aus dem Baltischen Bernst...
# 14  Footnotes and taxonomic names, in Die im Berns...
# 15  Pseudoskorpione (Cheliferidae) phoretisch auf ...
# 16  Redescription of Chelifer eucarpus Dalman (Ara...
# 17  Om insekter inneslutne i Copal; jemte beskrifn...
# 18  Pseudoskorpione im baltischen Bernstein und di...
# 19  Reinterpretation of Dracochela deprehendor (Ar...
# 20  The first Paleozoic pseudoscorpions (Arachnida...
# 21  Cheiridiidae in Dominikanischem Bernstein, mit...
# 22  Cheliferoid pseudoscorpions (Arachnida, Chelon...
# 23  Baltic amber fossil Garypinus electri Beier pr...
# 24  A sternophorid pseudoscorpion (Chelonethi) in ...
# 25  A new Geogarypus from Baltic amber Pseudoscorp...
# 26  Taxonomic names, in Phase-contrast synchrotron...
# 27  The first geogarypid (Pseudoscorpiones, Geogar...
# 28  Taxonomic names, in Description of a new fossi...
# 29  Pseudoscorpione im baltischen Bernstein aus de...
# 30  First fossil record of the pseudoscorpion fami...
# 31  A list of type and figured specimens of insect...
# 32  Taxonomic names, in A new chernetid pseudoscor...
# 33       Pseudoscorpione aus dem baltischen Bernstein
# 34                                                NaN
# 35                                                NaN
# 36  Pseudoscorpions (Arachnida, Chelonethi) in Mex...
# 37  Systematics, in The basal pseudoscorpion famil...
# 38                  Amber inclusions from New Zealand
# 39  The oldest chthonioid pseudoscorpion Arachnida...
#
#                                              pubtitle  pubvol  pubno  \
# 0                                       Palaeontology    34.0      4
# 1   Histoire Naturelle, Générale et Particulière d...     NaN    NaN
# 2               American Journal of Science, Series 4    44.0    263
# 3                                                 NaN     NaN    NaN
# 4                                       Geodiversitas    25.0      3
# 5   The Annals and Magazine of Natural History, Ni...     5.0    NaN
# 6   Bulletin of the Natural History Museum, Geolog...    56.0    NaN
# 7   Bulletin of the Southern California Academy of...    61.0    NaN
# 8   The World Spider Catalog, version 14.0. Americ...     NaN    NaN
# 9   Die in Bernstein Befindlichen Organischen Rest...     1.0      2
# 10          Zoological Journal of the Linnean Society   150.0    NaN
# 11  Stuttgarter Beiträge zur Naturkunde Serie B (G...    57.0    NaN
# 12  Stuttgarter Beiträge zur Naturkunde Serie B (G...    63.0    NaN
# 13  Stuttgarter Beiträge zur Naturkunde Serie B (G...    42.0    NaN
# 14  Die in Bernstein Befindlichen Organischen Rest...     1.0      2
# 15  Stuttgarter Beiträge zur Naturkunde Serie B (G...    71.0    NaN
# 16                                    Palaeodiversity     3.0    NaN
# 17  Kongliga Svenska Vetenskaps-Akademiens Handlingar  1825.0    NaN
# 18                                  Mikroscopie, Wien     1.0    NaN
# 19                                      Palaeontology    55.0    NaN
# 20                          American Museum Novitates  3009.0    NaN
# 21  Stuttgarter Beiträge zur Naturkunde Serie B (G...    75.0    NaN
# 22                                      Geodiversitas    31.0    NaN
# 23                  Arthropoda Selecta, Special Issue     1.0    NaN
# 24                         The Journal of Arachnology    26.0    NaN
# 25                                             Phegea    33.0    NaN
# 26                         Palaeontologia Electronica    15.0  2.17A
# 27                                   Vestnik Zoologii    46.0    NaN
# 28                                            Zootaxa  1305.0    NaN
# 29  Mitteilungen aus dem Geologisch-Paläontologisc...    24.0    NaN
# 30                                            Zootaxa  1393.0    NaN
# 31  Bulletin of the Natural History Museum, Geolog...    56.0    NaN
# 32                 Canadian Journal of Earth Sciences    51.0    NaN
# 33  Festschrift zum 60 Geburtstage von Professor D...     2.0    NaN
# 34  Histoire Abregée des Insectes qui se Trouvent ...     NaN    NaN
# 35  Elementa Entomologica. CXXXV. Tabulae aere Exc...     NaN    NaN
# 36          Boletín de la Sociedad Geológica Mexicana    68.0    NaN
# 37                                        Entomo-Info    27.0    NaN
# 38                                  Gondwana Research    56.0    NaN
# 39                              Zoologischer Anzeiger   273.0    NaN
#
#    firstpage lastpage
# 0        971      976
# 1          1      467
# 2        360      368
# 3        NaN      NaN
# 4        445      450
# 5        273      279
# 6         79       83
# 7        143      151
# 8        NaN      NaN
# 9          1      124
# 10       221      265
# 11         1       20
# 12         1       19
# 13         1       21
# 14         1      124
# 15         1       17
# 16        33       42
# 17       375      410
# 18       188      199
# 19       261      283
# 20         1       17
# 21         1       14
# 22        61       71
# 23       127      131
# 24       419      428
# 25        87       92
# 26         1       11
# 27       e33      e36
# 28        41       50
# 29        48       54
# 30        45       51
# 31        11       20
# 32       902      908
# 33       302      316
# 34         1      690
# 35       NaN      NaN
# 36        57       79
# 37         7       12
# 38       135      146
# 39       102      111

# %%
# Create a group based on the values in the 'author1last' column
author_group = author_df.groupby('author1last')

# Count how many times each author appears in our group
count_authors = author_group['author1last'].count()

count_authors
# Out:
# author1last
# Beier         3
# Clapham       1
# Cockerell     2
# Dalman        1
# Dunlop        1
# Geoffroy      1
# Harvey        1
# Henderickx    5
# Judson        9
# Koch          1
# Latreille     1
# Menge         1
# Pierce        1
# Riquelme      1
# Ross          1
# Schaeffer     1
# Schawaller    7
# Schmidt       1
# Shultz        1
# Name: author1last, dtype: int64

# %%
# Create a bar chart based off of the group series from before
author_chart = count_authors.plot(kind='bar')

# Set the xlabel and ylabel using class methods
author_chart.set_xlabel("Author")
author_chart.set_ylabel("Number of Works Cited")


plt.show()
plt.tight_layout()

# %%
# Create a group based on the values in the 'pubyr' column
pubyr_group = author_df.groupby('pubyr')

# Count how many times each pubyr appears in our group
count_pubyr = pubyr_group['pubyr'].count()

count_pubyr
# Out:
# pubyr
# 1762    1
# 1766    1
# 1802    1
# 1826    1
# 1854    2
# 1917    1
# 1920    1
# 1937    1
# 1947    1
# 1955    1
# 1962    1
# 1978    1
# 1980    2
# 1981    2
# 1991    2
# 1998    1
# 2000    2
# 2003    2
# 2005    1
# 2006    1
# 2007    2
# 2009    1
# 2010    1
# 2012    3
# 2013    1
# 2014    1
# 2016    2
# 2018    2
# 2020    1
# Name: pubyr, dtype: int64

# %%
# Create a bar chart based off of the group series from before
author_chart = count_pubyr.plot(kind='line')

# Set the xlabel and ylabel using class methods
author_chart.set_xlabel("Publish Year")
author_chart.set_ylabel("Number of Authors Published")


plt.show()
plt.tight_layout()

# %%
# Collect the user's input to search through our data frame
author_name = input("What authors's career would you like to look at?")
# Out:
# What authors's career would you like to look at?Beier

# %%
# Create a series that looks for a wrestler by name and then traces their wins from 2013 to 2016
authors_over_time = authors_over_hundred.loc[wrestler_name,["2013 Wins","2014 Wins", "2015 Wins", "2016 Wins"]]

# %%
# Create a list of the years that we will use as our x axis
years = [2013,2014,2015,2016]

# Plot our line that will be used to track a wrestler's wins over the years
plt.plot(years, wins_over_time, color="green", label="Wins")

# Plot our line that will be used to track a wrestler's losses over the years
plt.plot(years, losses_over_time, color="blue", label="Losses")

# Place a legend on the chart in what matplotlib believes to be the "best" location
plt.legend(loc="best")

plt.title(wrestler_name + "'s Recent Career")
plt.xlabel("Years")
plt.ylabel("Number of Wins/Losses")

# Print our chart to the screen
plt.show()

# %%
# Get number of citations by author name described in Burmese amber each year data
citation_data = citation_data["attacker_king"].value_counts()
defender_data = got_data["defender_king"].value_counts()

# %% [markdown]
# ##### extant_data cleaning....
# 1. Need to seperate the Authors and publication year of Suborder, Superfamily, family, tribe, and genera.
# 2. drop NaN? Doesn't that get "rid" of the entire row? If so, no go.

# %% [markdown]
# ## World Spider Catalog
# Dunlop, J. A., Penney, D. & Jekel, D. 2020. A summary list of fossil spiders and their relatives. In World Spider
# Catalog. Natural History Museum Bern, online at http://wsc.nmbe.ch, version 20.5, accessed on {4 October 2020}.

# %%
fossildata_from_WSC2020 = "WSC_data/WSC2020_pseudoscorpiones.csv"
WSC_data = pd.read_csv(fossildata_from_WSC2020)
WSC_data
# Out:
#                Order     SuperFamily         Family                Range  \
# 0    Paleosphyronida  Dracocheloidea  Dracochelidea    Devonian ‒ Recent
# 1   Heterospyhronida      Chtonoidea    Chthonoidea  Cretaceous ‒ Recent
# 2   Heterospyhronida      Chtonoidea    Chthoniidae  Cretaceous ‒ Recent
# 3   Heterospyhronida      Chtonoidea    Chthoniidae  Cretaceous ‒ Recent
# 4   Heterospyhronida      Chtonoidea    Chthoniidae  Cretaceous ‒ Recent
# ..               ...             ...            ...                  ...
# 80        Panctenata   Cheliferoidea      Withiidae   Paleogene ‒ Recent
# 81        Panctenata   Cheliferoidea      Withiidae   Paleogene ‒ Recent
# 82        Panctenata   Cheliferoidea      Withiidae   Paleogene ‒ Recent
# 83            indet.          indet.   NOMUM DUBIUM               indet.
# 84            indet.          indet.    NOMUM NUDUM               indet.
#
#                     Genus      Species                           Author  \
# 0              Dracochela  deprehendor  Schwaller, Shear & Bonamo, 1991
# 1                  indet.       indet.             Ahrens et al. (2019)
# 2            Chelignathus       kochii     Menge in Koch & Berendt 1854
# 3   Chthonius (Chthonius)       mengei                      Beier, 1937
# 4   Chthonius (Chthonius)    pristinus                  Schwaller, 1978
# ..                    ...          ...                              ...
# 80                 indet.       indet.          in Ahrens et al. (2019)
# 81          Beierowithius   sieboldtii   (Menge in Koch & Berendt 1854)
# 82                Withius     eucarpus                   (Dalman, 1826)
# 83               Chelifer  ehrenbergii        C.L. Koch & Berendt, 1854
# 84               Chelifer     fossilis                 Weyenbergh, 1874
#
#    Type Locality Type Age range
# 0         Gilboa       Devonian
# 1     Bitterfeld      Paleogene
# 2         Baltic      Paleogene
# 3         Baltic      Paleogene
# 4         Baltic      Paleogene
# ..           ...            ...
# 80    Bitterfeld      Paleogene
# 81        Baltic      Paleogene
# 82   East Africa     Quaternary
# 83        Baltic      Paleogene
# 84     Solnhofen       Jurassic
#
# [85 rows x 9 columns]

# %% [markdown]
# ##### WSC cleaning......
# 1. seperate the range into range_start and range_end.
# 2. seperate Author and pub. yr.
# 3. description authors vs. subsequent authors
# 4. seperate subgenera and genera

# %% [markdown]
# ## PBDB Data

# %%
PBDB_fossil_pscorps = "PBDB_data/PBDBreview_pseudoscorps.csv"
DF_pscorps_fossils = pd.read_csv(PBDB_fossil_pscorps)
DF_pscorps_fossils

# %%
PBDB_invalid_taxa = "PBDB_data/invalid_taxa.csv"
DF_invalid_taxa = pd.read_csv(PBDB_invalid_taxa)
DF_invalid_taxa

# %%
PBDB_references = "PBDB_data/references.csv"
DF_references = pd.read_csv(PBDB_references)
DF_references

# %%
PBDB_valid_taxa = "PBDB_data/valid_taxa.csv"
DF_valid_taxa = pd.read_csv(PBDB_valid_taxa)
DF_valid_taxa

# %%
PBDB_opinions = "PBDB_data/opinions.csv"
DF_opinions = pd.read_csv(PBDB_opinions)
DF_opinions
