# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Pseudoscorpions of the World
# Harvey, M.S. (2013). Pseudoscorpions of the World, version 3.0. Western Australian Museum, Perth. http://www.museum.wa.gov.au/catalogues/pseudoscorpions

# %%
full_pseudoscorpion_classification = "POW_data/pseudoscorp_full_classification.csv"
extant_data = pd.read_csv(full_pseudoscorpion_classification)

extant_data
# Out:
#       Kingdom      Phylum    Subphylum      Class             Order  \
# 0    Animalia  Arthropoda  Chelicerata  Arachnida  Pseudoscorpiones
# 1    Animalia  Arthropoda  Chelicerata  Arachnida  Pseudoscorpiones
# 2    Animalia  Arthropoda  Chelicerata  Arachnida  Pseudoscorpiones
# 3    Animalia  Arthropoda  Chelicerata  Arachnida  Pseudoscorpiones
# 4    Animalia  Arthropoda  Chelicerata  Arachnida  Pseudoscorpiones
# ..        ...         ...          ...        ...               ...
# 902  Animalia  Arthropoda  Chelicerata  Arachnida  Pseudoscorpiones
# 903  Animalia  Arthropoda  Chelicerata  Arachnida  Pseudoscorpiones
# 904  Animalia  Arthropoda  Chelicerata  Arachnida  Pseudoscorpiones
# 905  Animalia  Arthropoda  Chelicerata  Arachnida  Pseudoscorpiones
# 906  Animalia  Arthropoda  Chelicerata  Arachnida  Pseudoscorpiones
#
#                      Suborder                                Superfamilies  \
# 0    Epiocheirata Harvey 1992                      Chthonioidea Daday 1888
# 1    Epiocheirata Harvey 1992                      Chthonioidea Daday 1888
# 2    Epiocheirata Harvey 1992                      Chthonioidea Daday 1888
# 3    Epiocheirata Harvey 1992                      Chthonioidea Daday 1888
# 4    Epiocheirata Harvey 1992                      Chthonioidea Daday 1888
# ..                        ...                                          ...
# 902    Iocheirata Harvey 1992     Superfamily Neobisioidea Chamberlin 1930
# 903    Iocheirata Harvey 1992     Superfamily Neobisioidea Chamberlin 1930
# 904    Iocheirata Harvey 1992  Superfamily Sternophoroidea Chamberlin 1923
# 905    Iocheirata Harvey 1992  Superfamily Sternophoroidea Chamberlin 1923
# 906    Iocheirata Harvey 1992  Superfamily Sternophoroidea Chamberlin 1923
#
#                                               Family  \
# 0                             Chthoniidae Daday 1888
# 1                             Chthoniidae Daday 1888
# 2                             Chthoniidae Daday 1888
# 3    Dracochelidae Schawaller, Shear and Bonamo 1991
# 4                        Lechytiidae Chamberlin 1929
# ..                                               ...
# 902                Family Syarinidae Chamberlin 1930
# 903                Family Syarinidae Chamberlin 1930
# 904            Family Sternophoridae Chamberlin 1923
# 905            Family Sternophoridae Chamberlin 1923
# 906            Family Sternophoridae Chamberlin 1923
#
#                                 Subfamily                              Tribe  \
# 0                                     NaN            Ayyaloniini Ćurčić 2008
# 1                                     NaN              Chthoniini Daday 1888
# 2                                     NaN  Tyrannochthoniini Chamberlin 1962
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
# ..                                    ...                                ...
# 902  Subfamily Syarininae Chamberlin 1930                                NaN
# 903  Subfamily Syarininae Chamberlin 1930                                NaN
# 904                                   NaN                                NaN
# 905                                   NaN                                NaN
# 906                                   NaN                                NaN
#
#                                            Genera
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3    Dracochela Schawaller, Shear and Bonamo 1991
# 4                            Lechytia Balzan 1892
# ..                                            ...
# 902                     Pseudoblothrus Beier 1931
# 903                      Syarinus Chamberlin 1925
# 904                   Afrosternophorus Beier 1967
# 905                            Garyops Banks 1909
# 906                         Idiogaryops Hoff 1963
#
# [907 rows x 11 columns]

# %%
suborder = extant_data.Suborder.str.split(expand=True)
DF_suborder = pd.DataFrame(suborder)
DF_suborder.columns = ["Suborder", "SO_author", "SO_pubyr"]
DF_suborder
# Out:
#          Suborder SO_author SO_pubyr
# 0    Epiocheirata    Harvey     1992
# 1    Epiocheirata    Harvey     1992
# 2    Epiocheirata    Harvey     1992
# 3    Epiocheirata    Harvey     1992
# 4    Epiocheirata    Harvey     1992
# ..            ...       ...      ...
# 902    Iocheirata    Harvey     1992
# 903    Iocheirata    Harvey     1992
# 904    Iocheirata    Harvey     1992
# 905    Iocheirata    Harvey     1992
# 906    Iocheirata    Harvey     1992
#
# [907 rows x 3 columns]

# %%
DF_Superfamilies = pd.DataFrame(Superfamilies)
pat = '|'.join([r'\b{}\b'.format(w) for w in remove_words])

DF_Superfamilies.assign(new=DF_Superfamilies.replace(dict(string={pat: ''}), regex=True))

remove_words = ['Superfamily', 'Family', 'Subfamily']

DF_Superfamilies
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'new'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1070         try:
# -> 1071             loc = self.items.get_loc(item)
#    1072         except KeyError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     352                 raise KeyError(key)
# --> 353         return super().get_loc(key, method=method, tolerance=tolerance)
#     354
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'new'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-937e06f15b6a> in <module>
#       2 pat = '|'.join([r'\b{}\b'.format(w) for w in remove_words])
#       3
# ----> 4 DF_Superfamilies.assign(new=DF_Superfamilies.replace(dict(string={pat: ''}), regex=True))
#       5
#       6 remove_words = ['Superfamily', 'Family', 'Subfamily']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in assign(self, **kwargs)
#    3565
#    3566         for k, v in kwargs.items():
# -> 3567             data[k] = com.apply_if_callable(v, data)
#    3568         return data
#    3569
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2999         self._ensure_valid_index(value)
#    3000         value = self._sanitize_column(key, value)
# -> 3001         NDFrame._set_item(self, key, value)
#    3002
#    3003         # check if we are modifying a copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3622
#    3623     def _set_item(self, key, value) -> None:
# -> 3624         self._data.set(key, value)
#    3625         self._clear_item_cache()
#    3626
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1072         except KeyError:
#    1073             # This item wasn't present, just insert at end
# -> 1074             self.insert(len(self.items), item, value)
#    1075             return
#    1076
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1179         new_axis = self.items.insert(loc, item)
#    1180
# -> 1181         block = make_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1182
#    1183         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3039         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3040
# -> 3041     return klass(values, ndim=ndim, placement=placement)
#    3042
#    3043
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#    2587             values = np.array(values, dtype=object)
#    2588
# -> 2589         super().__init__(values, ndim=ndim, placement=placement)
#    2590
#    2591     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     123         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
#     124             raise ValueError(
# --> 125                 f"Wrong number of items passed {len(self.values)}, "
#     126                 f"placement implies {len(self.mgr_locs)}"
#     127             )
#
# ValueError: Wrong number of items passed 4, placement implies 1

# %%
Superfamilies = extant_data.Superfamilies.str.split(expand=True)

DF_Superfamilies = pd.DataFrame(Superfamilies)

pat = '|'.join([r'\b{}\b'.format(w) for w in remove_words])

DF_Superfamilies.assign(new=DF_Superfamilies.replace(dict(string={pat: ''}), regex=True))

remove_words = ['Superfamily', 'Family', 'Subfamily']

DF_Superfamilies
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'new'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1070         try:
# -> 1071             loc = self.items.get_loc(item)
#    1072         except KeyError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     352                 raise KeyError(key)
# --> 353         return super().get_loc(key, method=method, tolerance=tolerance)
#     354
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'new'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-766f52ebd7df> in <module>
#       5 pat = '|'.join([r'\b{}\b'.format(w) for w in remove_words])
#       6
# ----> 7 DF_Superfamilies.assign(new=DF_Superfamilies.replace(dict(string={pat: ''}), regex=True))
#       8
#       9 remove_words = ['Superfamily', 'Family', 'Subfamily']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in assign(self, **kwargs)
#    3565
#    3566         for k, v in kwargs.items():
# -> 3567             data[k] = com.apply_if_callable(v, data)
#    3568         return data
#    3569
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2999         self._ensure_valid_index(value)
#    3000         value = self._sanitize_column(key, value)
# -> 3001         NDFrame._set_item(self, key, value)
#    3002
#    3003         # check if we are modifying a copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3622
#    3623     def _set_item(self, key, value) -> None:
# -> 3624         self._data.set(key, value)
#    3625         self._clear_item_cache()
#    3626
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1072         except KeyError:
#    1073             # This item wasn't present, just insert at end
# -> 1074             self.insert(len(self.items), item, value)
#    1075             return
#    1076
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1179         new_axis = self.items.insert(loc, item)
#    1180
# -> 1181         block = make_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1182
#    1183         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3039         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3040
# -> 3041     return klass(values, ndim=ndim, placement=placement)
#    3042
#    3043
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#    2587             values = np.array(values, dtype=object)
#    2588
# -> 2589         super().__init__(values, ndim=ndim, placement=placement)
#    2590
#    2591     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     123         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
#     124             raise ValueError(
# --> 125                 f"Wrong number of items passed {len(self.values)}, "
#     126                 f"placement implies {len(self.mgr_locs)}"
#     127             )
#
# ValueError: Wrong number of items passed 4, placement implies 1

# %%
suborder = extant_data.Suborder.str.split(expand=True)
DF_suborder = pd.DataFrame(suborder)
DF_suborder.columns = ["Suborder", "SO_author", "SO_pubyr"]
DF_suborder

# %%
Superfamilies = extant_data.Superfamilies.str.split(expand=True)
DF_Superfamilies = pd.DataFrame(Superfamilies)
DF_Superfamilies.columns = ["Superfamilies", "SO_author", "SO_pubyr"]
DF_Superfamilies
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-62c7b0d7ef69> in <module>
#       1 Superfamilies = extant_data.Superfamilies.str.split(expand=True)
#       2 DF_Superfamilies = pd.DataFrame(Superfamilies)
# ----> 3 DF_Superfamilies.columns = ["Superfamilies", "SO_author", "SO_pubyr"]
#       4 DF_Superfamilies
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     659
#     660     def _set_axis(self, axis, labels) -> None:
# --> 661         self._data.set_axis(axis, labels)
#     662         self._clear_item_cache()
#     663
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     176         if new_len != old_len:
#     177             raise ValueError(
# --> 178                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     179                 f"values have {new_len} elements"
#     180             )
#
# ValueError: Length mismatch: Expected axis has 4 elements, new values have 3 elements

# %%
suborder = extant_data.Suborder.str.split(expand=True)
DF_suborder = pd.DataFrame(suborder)
DF_suborder.columns = ["Suborder", "SO_author", "SO_pubyr"]
DF_suborder

# %% [markdown]
# ##### extant_data cleaning....
# 1. Need to seperate the Authors and publication year of Suborder, Superfamily, family, tribe, and genera.
# 2. drop NaN? Doesn't that get "rid" of the entire row? If so, no go.

# %% [markdown]
# ## World Spider Catalog
# Dunlop, J. A., Penney, D. & Jekel, D. 2020. A summary list of fossil spiders and their relatives. In World Spider
# Catalog. Natural History Museum Bern, online at http://wsc.nmbe.ch, version 20.5, accessed on {4 October 2020}.

# %%
fossildata_from_WSC2020 = "WSC_data/WSC2020_pseudoscorpiones.csv"
WSC_data = pd.read_csv(fossildata_from_WSC2020)
WSC_data
# Out:
#                Order     SuperFamily         Family                Range  \
# 0    Paleosphyronida  Dracocheloidea  Dracochelidea    Devonian ‒ Recent
# 1   Heterospyhronida      Chtonoidea    Chthonoidea  Cretaceous ‒ Recent
# 2   Heterospyhronida      Chtonoidea    Chthoniidae  Cretaceous ‒ Recent
# 3   Heterospyhronida      Chtonoidea    Chthoniidae  Cretaceous ‒ Recent
# 4   Heterospyhronida      Chtonoidea    Chthoniidae  Cretaceous ‒ Recent
# ..               ...             ...            ...                  ...
# 80        Panctenata   Cheliferoidea      Withiidae   Paleogene ‒ Recent
# 81        Panctenata   Cheliferoidea      Withiidae   Paleogene ‒ Recent
# 82        Panctenata   Cheliferoidea      Withiidae   Paleogene ‒ Recent
# 83            indet.          indet.   NOMUM DUBIUM               indet.
# 84            indet.          indet.    NOMUM NUDUM               indet.
#
#                     Genus      Species                           Author  \
# 0              Dracochela  deprehendor  Schwaller, Shear & Bonamo, 1991
# 1                  indet.       indet.             Ahrens et al. (2019)
# 2            Chelignathus       kochii     Menge in Koch & Berendt 1854
# 3   Chthonius (Chthonius)       mengei                      Beier, 1937
# 4   Chthonius (Chthonius)    pristinus                  Schwaller, 1978
# ..                    ...          ...                              ...
# 80                 indet.       indet.          in Ahrens et al. (2019)
# 81          Beierowithius   sieboldtii   (Menge in Koch & Berendt 1854)
# 82                Withius     eucarpus                   (Dalman, 1826)
# 83               Chelifer  ehrenbergii        C.L. Koch & Berendt, 1854
# 84               Chelifer     fossilis                 Weyenbergh, 1874
#
#    Type Locality Type Age range
# 0         Gilboa       Devonian
# 1     Bitterfeld      Paleogene
# 2         Baltic      Paleogene
# 3         Baltic      Paleogene
# 4         Baltic      Paleogene
# ..           ...            ...
# 80    Bitterfeld      Paleogene
# 81        Baltic      Paleogene
# 82   East Africa     Quaternary
# 83        Baltic      Paleogene
# 84     Solnhofen       Jurassic
#
# [85 rows x 9 columns]

# %% [markdown]
# ##### WSC cleaning......
# 1. seperate the range into range_start and range_end.
# 2. seperate Author and pub. yr.
# 3. description authors vs. subsequent authors
# 4. seperate subgenera and genera

# %% [markdown]
# ## PBDB Data

# %%
PBDB_fossil_pscorps = "PBDB_data/PBDBreview_pseudoscorps.csv"
DF_pscorps_fossils = pd.read_csv(PBDB_fossil_pscorps)
DF_pscorps_fossils

# %%
PBDB_invalid_taxa = "PBDB_data/invalid_taxa.csv"
DF_invalid_taxa = pd.read_csv(PBDB_invalid_taxa)
DF_invalid_taxa

# %%
PBDB_references = "PBDB_data/references.csv"
DF_references = pd.read_csv(PBDB_references)
DF_references

# %%
PBDB_valid_taxa = "PBDB_data/valid_taxa.csv"
DF_valid_taxa = pd.read_csv(PBDB_valid_taxa)
DF_valid_taxa

# %%
PBDB_opinions = "PBDB_data/opinions.csv"
DF_opinions = pd.read_csv(PBDB_opinions)
DF_opinions
